# %%
import numpy as np
import matplotlib.pyplot as plt

time = np.array([0,2,4,6,8,10,12,14]);
r1 = np.array([297.99, 295.92, 294.81, 294.33, 294.18, 294.04, 293.90, 293.75])
plt.plot(time, r1, 'o');
plt.axvline(x=0)

m, b = np.polyfit(time[4:], r1[4:], 1)
plt.plot(time, m * time + b )


plt.title('Reaction Profile of Trial 1 at 298K')
plt.xlabel('Reaction Progress (s) ± 0.001s')
plt.ylabel('Temperature (K) ± 0.01 K')

plt.show()
c = 298-b
print('Corrected Final Temperature of Trial 1: ', "{:.2f}".format(b), 'K') 
print('Temperature Change: ', "{:.2f}".format(c), 'K')
# Out:
# Corrected Final Temperature of Trial 1:  294.75 K
# Temperature Change:  3.25 K

# %%
import numpy as np
import matplotlib.pyplot as plt

time = np.array([0,2,4,6,8,10,12,14]);
r1 = np.array([297.97, 295.89, 294.78, 294.32, 294.17, 294.01, 293.86, 293.70])
plt.plot(time, r1, 'o');
plt.axvline(x=0)

m, b = np.polyfit(time[4:], r1[4:], 1)
plt.plot(time, m * time + b )


plt.title('Reaction Profile of Trial 2 at 298K')
plt.xlabel('Reaction Progress (s) ± 0.001s')
plt.ylabel('Temperature (K) ± 0.01 K')

plt.show()
c = 298-b
print('Corrected Final Temperature of Trial 2: ', "{:.2f}".format(b), 'K') 
print('Temperature Change: ', "{:.2f}".format(c), 'K')
# Out:
# Corrected Final Temperature of Trial 2:  294.79 K
# Temperature Change:  3.21 K

# %%
import numpy as np
import matplotlib.pyplot as plt

time = np.array([0,2,4,6,8,10,12,14]);
r1 = np.array([298.00, 295.89, 294.77, 294.28, 294.14, 293.99, 293.84, 293.70])
plt.plot(time, r1, 'o');
plt.axvline(x=0)

m, b = np.polyfit(time[4:], r1[4:], 1)
plt.plot(time, m * time + b )


plt.title('Reaction Profile of Trial 3 at 298K')
plt.xlabel('Reaction Progress (s) ± 0.001s')
plt.ylabel('Temperature (K) ± 0.01 K')

plt.show()
c = 298-b
print('Corrected Final Temperature of Trial 3: ', "{:.2f}".format(b), 'K') 
print('Temperature Change: ', "{:.2f}".format(c), 'K')
# Out:
# Corrected Final Temperature of Trial 3:  294.73 K
# Temperature Change:  3.27 K
