# %%
import numpy as np
import matplotlib.pyplot as plt

time = np.array([0,2,4,6,8,10,12,14]);
r1 = np.array([303.00, 300.81, 299.66, 299.16, 298.99, 298.83, 298.67, 298.52])
plt.plot(time, r1, 'o');
plt.axvline(x=0)

m, b = np.polyfit(time[5:], r1[5:], 1)
plt.plot(time, m * time + b )


plt.title('Reaction Profile of Trial 1 at 303K')
plt.xlabel('Reaction Progress (s) ± 0.001s')
plt.ylabel('Temperature (K) ± 0.01 K')

plt.show()
c = 303-b
print('Corrected Final Temperature of Trial 1: ', "{:.2f}".format(b), 'K') 
print('Temperature Change: ', "{:.2f}".format(c), 'K')
# Out:
# Corrected Final Temperature of Trial 1:  299.60 K
# Temperature Change:  3.40 K

# %%
import numpy as np
import matplotlib.pyplot as plt

time = np.array([0,2,4,6,8,10,12,14]);
r1 = np.array([303.00, 300.83, 299.67, 299.19, 299.05, 298.91, 298.78, 298.63])
plt.plot(time, r1, 'o');
plt.axvline(x=0)

m, b = np.polyfit(time[5:], r1[5:], 1)
plt.plot(time, m * time + b )


plt.title('Reaction Profile of Trial 2 at 303K')
plt.xlabel('Reaction Progress (s) ± 0.001s')
plt.ylabel('Temperature (K) ± 0.01 K')

plt.show()
c = 303-b
print('Corrected Final Temperature of Trial 2: ', "{:.2f}".format(b), 'K') 
print('Temperature Change: ', "{:.2f}".format(c), 'K')
# Out:
# Corrected Final Temperature of Trial 2:  299.61 K
# Temperature Change:  3.39 K

# %%
import numpy as np
import matplotlib.pyplot as plt

time = np.array([0,2,4,6,8,10,12,14]);
r1 = np.array([303.00, 300.77, 299.56, 299.06, 298.90, 298.75, 298.60, 298.46])
plt.plot(time, r1, 'o');
plt.axvline(x=0)

m, b = np.polyfit(time[5:], r1[5:], 1)
plt.plot(time, m * time + b )


plt.title('Reaction Profile of Trial 3 at 303K')
plt.xlabel('Reaction Progress (s) ± 0.001s')
plt.ylabel('Temperature (K) ± 0.01 K')

plt.show()
c = 303-b
print('Corrected Final Temperature of Trial 3: ', "{:.2f}".format(b), 'K') 
print('Temperature Change: ', "{:.2f}".format(c), 'K')
# Out:
# Corrected Final Temperature of Trial 3:  299.47 K
# Temperature Change:  3.53 K
