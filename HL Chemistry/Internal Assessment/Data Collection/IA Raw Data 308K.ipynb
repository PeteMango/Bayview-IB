# %%
import numpy as np
import matplotlib.pyplot as plt

time = np.array([0,2,4,6,8,10,12,14]);
r1 = np.array([308.00, 305.74, 304.57, 304.05, 303.88, 303.72, 303.56, 303.41])
plt.plot(time, r1, 'o');
plt.axvline(x=0)

m, b = np.polyfit(time[5:], r1[5:], 1)
plt.plot(time, m * time + b )


plt.title('Reaction Profile of Trial 1 at 308K')
plt.xlabel('Reaction Progress (s) ± 0.001s')
plt.ylabel('Temperature (K) ± 0.01 K')

plt.show()
c = 308-b
print('Corrected Final Temperature of Trial 1: ', "{:.2f}".format(b), 'K') 
print('Temperature Change: ', "{:.2f}".format(c), 'K')
# Out:
# Corrected Final Temperature of Trial 1:  304.49 K
# Temperature Change:  3.51 K

# %%
import numpy as np
import matplotlib.pyplot as plt

time = np.array([0,2,4,6,8,10,12,14]);
r1 = np.array([308.00, 305.77, 304.58, 304.09, 303.95, 303.81, 303.68, 303.53])
plt.plot(time, r1, 'o');
plt.axvline(x=0)

m, b = np.polyfit(time[5:], r1[5:], 1)
plt.plot(time, m * time + b )


plt.title('Reaction Profile of Trial 2 at 308K')
plt.xlabel('Reaction Progress (s) ± 0.001s')
plt.ylabel('Temperature (K) ± 0.01 K')

plt.show()
c = 308-b
print('Corrected Final Temperature of Trial 2: ', "{:.2f}".format(b), 'K') 
print('Temperature Change: ', "{:.2f}".format(c), 'K')
# Out:
# Corrected Final Temperature of Trial 2:  304.51 K
# Temperature Change:  3.49 K

# %%
import numpy as np
import matplotlib.pyplot as plt

time = np.array([0,2,4,6,8,10,12,14]);
r1 = np.array([308.00, 305.71, 304.46, 303.95, 303.79, 303.64, 303.49, 303.35])
plt.plot(time, r1, 'o');
plt.axvline(x=0)

m, b = np.polyfit(time[5:], r1[5:], 1)
plt.plot(time, m * time + b )


plt.title('Reaction Profile of Trial 3 at 308K')
plt.xlabel('Reaction Progress (s) ± 0.001s')
plt.ylabel('Temperature (K) ± 0.01 K')

plt.show()
c = 308-b
print('Corrected Final Temperature of Trial 3: ', "{:.2f}".format(b), 'K') 
print('Temperature Change: ', "{:.2f}".format(c), 'K')
# Out:
# Corrected Final Temperature of Trial 3:  304.36 K
# Temperature Change:  3.64 K
