# %%
import numpy as np
import matplotlib.pyplot as plt

time = np.array([0,2,4,6,8,10,12,14]);
r1 = np.array([317.98, 315.65, 314.41, 313.89, 313.74, 313.60, 313.46, 313.30])
plt.plot(time, r1, 'o');
plt.axvline(x=0)

m, b = np.polyfit(time[4:], r1[4:], 1)
plt.plot(time, m * time + b )


plt.title('Reaction Profile of Trial 1 at 318K')
plt.xlabel('Reaction Progress (s) ± 0.001s')
plt.ylabel('Temperature (K) ± 0.01 K')

plt.show()
c = 318-b
print('Corrected Final Temperature of Trial 1: ', "{:.2f}".format(b), 'K') 
print('Temperature Change: ', "{:.2f}".format(c), 'K')
# Out:
# Corrected Final Temperature of Trial 1:  314.33 K
# Temperature Change:  3.67 K

# %%
import numpy as np
import matplotlib.pyplot as plt

time = np.array([0,2,4,6,8,10,12,14]);
r1 = np.array([317.97, 315.61, 314.35, 313.85, 313.69, 313.55, 313.39, 313.23])
plt.plot(time, r1, 'o');
plt.axvline(x=0)

m, b = np.polyfit(time[4:], r1[4:], 1)
plt.plot(time, m * time + b )


plt.title('Reaction Profile of Trial 2 at 318K')
plt.xlabel('Reaction Progress (s) ± 0.001s')
plt.ylabel('Temperature (K) ± 0.01 K')

plt.show()
c = 318-b
print('Corrected Final Temperature of Trial 2: ', "{:.2f}".format(b), 'K') 
print('Temperature Change: ', "{:.2f}".format(c), 'K')
# Out:
# Corrected Final Temperature of Trial 2:  314.31 K
# Temperature Change:  3.69 K

# %%
import numpy as np
import matplotlib.pyplot as plt

time = np.array([0,2,4,6,8,10,12,14]);
r1 = np.array([318.02, 315.64, 314.38, 313.86, 313.71, 313.57, 313.42, 313.27])
plt.plot(time, r1, 'o');
plt.axvline(x=0)

m, b = np.polyfit(time[4:], r1[4:], 1)
plt.plot(time, m * time + b )


plt.title('Reaction Profile of Trial 3 at 318K')
plt.xlabel('Reaction Progress (s) ± 0.001s')
plt.ylabel('Temperature (K) ± 0.01 K')

plt.show()
c = 318-b
print('Corrected Final Temperature of Trial 3: ', "{:.2f}".format(b), 'K') 
print('Temperature Change: ', "{:.2f}".format(c), 'K')
# Out:
# Corrected Final Temperature of Trial 3:  314.30 K
# Temperature Change:  3.70 K
